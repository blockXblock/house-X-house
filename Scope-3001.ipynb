# %%
import pandas as pd

# %%
1+1
# Out:
# 2

# %%
df = pd.read_csv("JG-J-WORKING DOCUMENT_Ecoblock Scope Table - Redhorse Rev.2021.11.csv")

# %%
# !pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 4.7 MB/s
# ...

# %%
df.columns
# Out:
# Index(['template: Table 1'], dtype='object')

# %%
pd.set_option('display.max_rows', None)

# %%
df3001 = pd.read_excel("WORKING DOCUMENT_Ecoblock Scope Table - Redhorse Rev.2021.11.23.xlsx",sheet_name= "Scope - House 3001", engine='openpyxl')
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
# %whos DataFrame
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# df3001     DataFrame        Unnamed: 0           <...>                    NaN

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
print(df3001)
# Out:
#     Unnamed: 0                                  RHC Draft 3.5.21  \
# 0          NaN                        PROJECT NAME AND ADDRESSS
# 1    Cost Code                                          Division
# 2          NaN                          1 - General Requirements
# 3          NaN  1.1 Protection & Janitorial Cleanup & COVID IDAP
# 4          NaN               2 - Existing Conditions (Site Work)
# 5          NaN                                  2.1 French Drain
# 6          NaN                                       Install new
# 7          NaN                  2.2 Water Management in Basement
# 8          NaN                                       Install new
# 9          NaN             2.3 Grey Water (Laundry to Landscape)
# 10         NaN                 6 - Wood, Plastics and Composites
# 11         NaN                               6.1 Rough Carpentry
# 12         NaN                                             Labor
# ...
